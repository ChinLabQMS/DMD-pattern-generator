# %% [markdown]
# ## Generate sequence of binary patterns and pack to RGB frames
# ### Setup

# %%
from utils import BinarySequence, Painter

save_dir = 'resources/'
painter = Painter()

# %% [markdown]
# ### A series of patterns with numbers

# %%
num_frames = 96
sequence = BinarySequence(num_frames)

for i in range(num_frames):
    sequence.drawPatternOnFrame(i, painter.drawText(str(i+1)), color=1)
sequence.saveRGBFrames(save_dir + '/packed_video/numbers/', 'numbers')
sequence.saveBinaryFrames(save_dir + '/packed_video/numbers/binary/', 'numbers')
sequence.saveSequenceToGIF(save_dir + '/packed_video/numbers/', 'numbers')
# Out:
# DMD pattern saved as: .\resources\packed_video\numbers\RGB_1_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\template\RGB_1_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\RGB_2_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\template\RGB_2_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\RGB_3_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\template\RGB_3_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\RGB_4_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\template\RGB_4_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_1_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_1_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_2_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_2_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_3_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_3_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_4_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_4_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_5_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_5_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_6_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_6_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_7_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_7_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_8_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_8_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_9_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_9_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_10_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_10_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_11_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_11_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_12_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_12_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_13_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_13_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_14_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_14_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_15_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_15_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_16_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_16_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_17_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_17_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_18_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_18_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_19_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_19_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_20_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_20_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_21_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_21_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_22_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_22_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_23_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_23_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_24_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_24_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_25_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_25_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_26_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_26_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_27_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_27_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_28_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_28_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_29_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_29_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_30_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_30_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_31_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_31_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_32_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_32_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_33_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_33_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_34_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_34_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_35_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_35_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_36_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_36_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_37_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_37_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_38_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_38_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_39_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_39_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_40_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_40_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_41_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_41_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_42_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_42_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_43_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_43_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_44_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_44_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_45_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_45_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_46_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_46_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_47_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_47_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_48_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_48_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_49_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_49_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_50_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_50_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_51_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_51_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_52_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_52_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_53_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_53_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_54_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_54_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_55_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_55_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_56_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_56_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_57_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_57_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_58_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_58_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_59_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_59_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_60_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_60_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_61_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_61_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_62_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_62_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_63_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_63_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_64_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_64_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_65_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_65_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_66_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_66_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_67_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_67_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_68_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_68_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_69_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_69_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_70_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_70_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_71_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_71_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_72_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_72_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_73_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_73_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_74_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_74_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_75_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_75_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_76_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_76_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_77_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_77_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_78_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_78_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_79_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_79_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_80_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_80_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_81_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_81_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_82_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_82_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_83_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_83_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_84_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_84_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_85_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_85_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_86_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_86_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_87_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_87_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_88_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_88_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_89_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_89_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_90_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_90_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_91_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_91_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_92_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_92_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_93_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_93_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_94_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_94_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_95_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_95_numbers.bmp
# DMD pattern saved as: .\resources\packed_video\numbers\binary\Binary_96_numbers.bmp
# Template image saved as: .\resources\packed_video\numbers\binary\template\Binary_96_numbers.bmp
# GIF file saved as: .\resources\packed_video\numbers\numbers.gif

# %% [markdown]
# ### A series of white bands with increasing widths

# %%
num = 96
sequence = BinarySequence(num)

for i in range(num):
    sequence.drawPatternOnFrame(i, painter.drawAngledLine(row_offset=0, width=10*(i+1), center=True), color=1)
sequence.saveRGBFrames(save_dir + '/packed_video/expanding_band/', 'white_band')
sequence.saveBinaryFrames(save_dir + '/packed_video/expanding_band/binary/', 'white_band')
sequence.saveSequenceToGIF(save_dir + '/packed_video/expanding_band/', 'white_band')
# Out:
# DMD pattern saved as: .\resources\packed_video\expanding_band\RGB_1_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\template\RGB_1_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\RGB_2_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\template\RGB_2_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\RGB_3_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\template\RGB_3_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\RGB_4_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\template\RGB_4_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_1_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_1_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_2_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_2_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_3_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_3_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_4_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_4_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_5_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_5_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_6_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_6_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_7_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_7_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_8_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_8_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_9_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_9_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_10_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_10_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_11_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_11_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_12_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_12_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_13_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_13_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_14_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_14_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_15_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_15_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_16_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_16_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_17_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_17_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_18_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_18_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_19_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_19_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_20_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_20_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_21_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_21_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_22_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_22_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_23_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_23_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_24_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_24_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_25_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_25_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_26_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_26_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_27_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_27_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_28_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_28_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_29_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_29_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_30_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_30_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_31_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_31_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_32_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_32_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_33_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_33_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_34_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_34_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_35_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_35_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_36_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_36_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_37_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_37_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_38_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_38_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_39_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_39_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_40_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_40_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_41_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_41_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_42_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_42_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_43_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_43_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_44_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_44_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_45_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_45_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_46_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_46_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_47_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_47_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_48_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_48_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_49_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_49_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_50_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_50_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_51_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_51_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_52_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_52_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_53_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_53_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_54_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_54_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_55_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_55_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_56_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_56_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_57_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_57_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_58_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_58_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_59_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_59_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_60_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_60_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_61_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_61_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_62_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_62_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_63_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_63_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_64_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_64_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_65_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_65_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_66_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_66_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_67_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_67_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_68_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_68_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_69_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_69_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_70_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_70_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_71_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_71_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_72_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_72_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_73_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_73_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_74_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_74_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_75_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_75_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_76_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_76_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_77_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_77_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_78_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_78_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_79_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_79_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_80_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_80_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_81_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_81_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_82_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_82_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_83_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_83_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_84_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_84_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_85_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_85_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_86_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_86_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_87_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_87_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_88_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_88_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_89_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_89_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_90_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_90_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_91_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_91_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_92_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_92_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_93_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_93_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_94_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_94_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_95_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_95_white_band.bmp
# DMD pattern saved as: .\resources\packed_video\expanding_band\binary\Binary_96_white_band.bmp
# Template image saved as: .\resources\packed_video\expanding_band\binary\template\Binary_96_white_band.bmp
# GIF file saved as: .\resources\packed_video\expanding_band\white_band.gif

# %% [markdown]
# ### A series of filled dark circles with decreasing radii

# %%
r_start = 260
r_end = 20
r_step = 5

r_range = list(range(r_start, r_end, -r_step))
num_frames = len(r_range)
num_frames
# Out:
# 48

# %%
sequence = BinarySequence(num_frames)

for i, r in enumerate(r_range):
    sequence.drawPatternOnFrame(i, painter.drawCircle(radius=r), color=0)
sequence.saveRGBFrames(save_dir + f'/packed_video/shrinking_dark_circle_start-{r_start}_end-{r_end}_step-{r_step}/', 'shrinking_dark_circle')
sequence.saveBinaryFrames(save_dir + f'/packed_video/shrinking_dark_circle_start-{r_start}_end-{r_end}_step-{r_step}/binary/', 'shrinking_dark_circle')
sequence.saveSequenceToGIF(save_dir + f'/packed_video/shrinking_dark_circle_start-{r_start}_end-{r_end}_step-{r_step}/', 'shrinking_dark_circle')
# Out:
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\RGB_1_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\template\RGB_1_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\RGB_2_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\template\RGB_2_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_1_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_1_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_2_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_2_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_3_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_3_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_4_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_4_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_5_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_5_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_6_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_6_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_7_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_7_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_8_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_8_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_9_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_9_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_10_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_10_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_11_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_11_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_12_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_12_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_13_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_13_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_14_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_14_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_15_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_15_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_16_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_16_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_17_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_17_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_18_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_18_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_19_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_19_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_20_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_20_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_21_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_21_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_22_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_22_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_23_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_23_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_24_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_24_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_25_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_25_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_26_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_26_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_27_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_27_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_28_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_28_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_29_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_29_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_30_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_30_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_31_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_31_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_32_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_32_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_33_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_33_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_34_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_34_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_35_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_35_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_36_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_36_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_37_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_37_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_38_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_38_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_39_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_39_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_40_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_40_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_41_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_41_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_42_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_42_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_43_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_43_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_44_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_44_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_45_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_45_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_46_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_46_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_47_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_47_shrinking_dark_circle.bmp
# DMD pattern saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\Binary_48_shrinking_dark_circle.bmp
# Template image saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\binary\template\Binary_48_shrinking_dark_circle.bmp
# GIF file saved as: .\resources\packed_video\shrinking_dark_circle_start-260_end-20_step-5\shrinking_dark_circle.gif
