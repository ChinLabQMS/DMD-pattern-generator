# %% [markdown]
# ### Setup

# %%
from utils import GrayscalePainter, Frame
from itertools import product

import numpy as np
import matplotlib.pyplot as plt

save_dir = 'resources/'

dmd = Frame()
painter = GrayscalePainter(nrows=dmd.real_nrows, ncols=dmd.real_ncols, dither_method='Floyd-Steinberg')

# %%
dmd.dmd_nrows, dmd.dmd_ncols, dmd.real_nrows, dmd.real_ncols
# Out:
# (1140, 912, 1482, 1481)

# %% [markdown]
# ### Discrete Fourier Transform

# %%
w = 5
dmd.drawPattern(painter.drawHorizontalStrips(width=w), color=1)
dmd.getTemplateImage()
# Out:
# <PIL.Image.Image image mode=RGB size=1481x1482>

# %%
real_array = dmd.real_array.sum(axis=2)
real_array[dmd.bg_rows, dmd.bg_cols] = 0

plt.figure(figsize=(10, 10))
plt.imshow(real_array, cmap='gray')
plt.show()

# %%
fourier = np.fft.fft2(real_array)
fourier.shape
# Out:
# (1482, 1481)

# %%
fourier = np.fft.fftshift(fourier)
fourier = np.abs(fourier)

plt.figure(figsize=(20, 20))
plt.imshow(fourier, cmap='gray')
plt.show()
